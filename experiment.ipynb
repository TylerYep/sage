# %%
import dataLoader
import json

# %%
activity = dataLoader._loadItem('p1', 'activities')

# %%
activity
# Out:
# {'1a24a94753c7dd348ba37c626e76f431': [[9, '2017-06-08 12:39:15'],
#   [3, '2017-06-08 12:39:35'],
#   [399, '2017-06-08 12:40:39'],
#   [9, '2017-06-08 12:40:49'],
#   [3, '2017-06-08 12:40:56'],
#   [0, '2017-06-08 12:41:07'],
#   [0, '2017-06-09 16:51:32']],
#  '4efe87631c4f2195e0482694ed53c502': [[3, '2017-04-05 00:44:22'],
#   [0, '2017-04-05 00:44:28']],
#  '1009b85282860ddc20a4f17aceb44a75': [[0, '2017-02-10 00:28:17']],
#  '7973085d7ae63c9bb1eef28859b8a6d6': [[2, '2017-03-06 04:31:48'],
#   [101, '2017-03-06 04:31:57'],
#   [46, '2017-03-06 04:32:07'],
#   [44, '2017-03-06 04:32:14'],
#   [8, '2017-03-06 04:32:20'],
#   [77, '2017-03-06 04:32:40'],
#   [430, '2017-03-06 04:32:58'],
#   [0, '2017-03-06 04:33:15']],
#  '83dc18f12d65811681bddb09dad86a95': [[196, '2017-06-07 23:09:20'],
#   [66, '2017-06-07 23:09:30'],
#   [19, '2017-06-07 23:09:37'],
#   [159, '2017-06-07 23:09:50'],
#   [159, '2017-06-07 23:13:15'],
#   [8, '2017-06-07 23:13:24'],
# ...

# %%
with open('p1/activities-1.json', 'w') as f:
    json.dump(activity, f, indent=2)
